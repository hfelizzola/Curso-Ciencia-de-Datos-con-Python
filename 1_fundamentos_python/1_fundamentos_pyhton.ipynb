# %% [markdown]
# <a href="https://colab.research.google.com/github/hfelizzola/Curso-Ciencia-de-Datos-con-Python/blob/main/1_fundamentos_python/1_fundamentos_pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 2. Fundamentos de Python para Ciencia de Datos
#
# **Curso:** Ciencia de Datos con Python
# **Semana:** 2
# **Tema:** Fundamentos de Python para Ciencia de Datos
# **Modalidad:** Notebook (teoría + práctica guiada)

# %% [markdown]
# ---
# ## ¿Qué aprenderás hoy?
#
# Al finalizar este notebook podrás:
#
# 1. Entender y usar correctamente los **tipos de datos** más comunes en Python.
# 2. Manipular **strings** para limpieza básica de datos.
# 3. Trabajar con **estructuras de datos** (listas, diccionarios, conjuntos) para representar información.
# 4. Aplicar **control de flujo** (`if`, `for`) para filtrar y transformar datos.
# 5. Crear **funciones** reutilizables para automatizar tareas típicas de análisis.
# 6. Producir un **mini-reporte reproducible** en texto a partir de datos simples.
#
# ---
#
# ## Prerrequisitos
#
# - Conocer qué es una variable y qué significa “ejecutar código”.
# - No se requiere experiencia previa con NumPy o pandas (eso inicia la próxima semana).
#
# ---
#
# ## Agenda
#
# 1. Notebook workflow y reproducibilidad
# 2. Variables y tipos de datos
# 3. Strings para limpieza básica
# 4. Estructuras de datos
# 5. Control de flujo
# 6. Funciones
# 7. Pythonic tools (built-ins + comprehensions)
# 8. Caso integrador
# 9. Cierre y puente a NumPy/pandas
#
# ---
#
# ## Reglas de trabajo (importante)
#
# - Ejecuta las celdas **en orden** (de arriba hacia abajo).
# - Si algo sale raro, usa: **Entorno de Ejecución → Reiniciar sesión y ejecutar todo**.
# - En los ejercicios, primero intenta tú y luego mira la solución.

# %% [markdown]
# # 1. Notebook workflow y reproducibilidad
#
# En ciencia de datos, **el código no solo debe funcionar**, sino que debe ser:
#
# - **Reproducible**: cualquier persona debe obtener los mismos resultados.
# - **Ordenado**: el notebook debe ejecutarse de arriba hacia abajo sin errores.
# - **Explicable**: el análisis debe entenderse leyendo el notebook.
#
# En este curso trabajaremos con **Google Colab**, que ejecuta notebooks en la nube.

# %% [markdown]
# ## 1.1 Tipos de celdas en Google Colab
#
# En Google Colab existen dos tipos principales de celdas:
#
# - **Texto (Markdown)** → explicaciones, títulos, notas.
# - **Código (Python)** → instrucciones que se ejecutan.
#
# Atajos útiles:
# - **Ctrl + Enter** → ejecutar celda
# - **Shift + Enter** → ejecutar celda ir a siguiente

# %%
# Esta es una celda de código
print("Hola, Ciencia de Datos")
# Out:
# Hola, Ciencia de Datos

# %% [markdown]
# ## 1.2 El orden de ejecución importa
#
# En Google Colab, las celdas **NO se ejecutan automáticamente en orden**.
#
# El resultado de una celda depende de:
# - qué celdas se ejecutaron antes,
# - en qué orden se ejecutaron.
#
# Esto puede producir resultados incorrectos **sin que Colab muestre un error**.

# %%
# Definimos primero la variable
x = 10
print("x =", x)
# Out:
# x = 10

# %%
# ⚠️ ¿Qué pasa si ejecutas esta celda antes de la anterior?
print("x + 5 =", x + 5)
# Out:
# x + 5 = 15

# %% [markdown]
# 💡 Discusión: *¿Por qué a veces esta celda funciona y a veces no?*

# %% [markdown]
# ## 1.3 Runtime en Google Colab
#
# En Colab, la **sesión** es el entorno donde se ejecuta Python.
#
# Características importantes:
# - La sesión **recuerda variables y funciones**.
# - Si la sesión se reinicia, **todo se borra**.
# - La sesión puede desconectarse automáticamente por inactividad.
#
# Menú clave:
# **Entorno de ejecución → Reiniciar la sesión**

# %% [markdown]
# ## 1.4 ¿Qué significa reproducibilidad en Colab?
#
# Un notebook reproducible en Google Colab cumple:
#
# 1. Se ejecuta correctamente desde la **primera celda**.
# 2. Produce los **mismos resultados** cada vez.
# 3. No depende de ejecuciones previas ocultas de la sesión.
#
# Antes de entregar un trabajo en Colab, **siempre** debes:
# **Reiniciar entorno de ejecución → Ejecutar todas las celdas**.

# %%
import random

muestra = [random.randint(1, 10) for _ in range(5)]
muestra
# Out:
# [6, 5, 3, 4, 6]

# %% [markdown]
# ### Controlando la aleatoriedad
#
# Para que los resultados sean reproducibles, debemos **fijar la semilla** del generador aleatorio.

# %%
import random
random.seed(42) # Configuración para fijar semilla

muestra = [random.randint(1, 10) for _ in range(5)]
muestra
# Out:
# [2, 1, 5, 4, 4]

# %% [markdown]
# Mas adelante veremos otras funciones que permiten fijar la semilla para garantizar la reproducibilidad de los resultados.

# %% [markdown]
# ## 1.5 Errores comunes en Google Colab
#
# ❌ Ejecutar celdas al azar
# ❌ No reiniciar el entorno antes de entregar
# ❌ Modificar datos sin documentarlo
# ❌ Resultados que solo funcionan “porque ya había corrido algo”
#
# **Buenas prácticas:**
#
# ✔️ Ejecutar siempre de arriba hacia abajo
# ✔️ Reiniciar runtime antes de entregar
# ✔️ Usar Markdown para explicar
# ✔️ Fijar semillas cuando hay aleatoriedad

# %% [markdown]
# ## 1.6 Mini-ejercicio (5 minutos)
#
# 1. Ve a **Entorno de ejecución → Reiniciar entorno de ejecución**.
# 2. Ejecuta **todas las celdas** del notebook en orden.
# 3. Cambia el valor de `random.seed`.
# 4. Responde:
#    - ¿Qué resultados cambian?
#    - ¿Cuáles no deberían cambiar nunca?

# %% [markdown]
# # 2. Variables y tipos de datos en Python
#
# En ciencia de datos, **la mayoría de los errores no son matemáticos**, sino errores de **tipos de datos**.
#
# Ejemplos reales:
# - números leídos como texto,
# - fechas tratadas como strings,
# - valores faltantes mal representados.
#
# Por eso, entender los **tipos de datos básicos de Python** es fundamental.

# %% [markdown]
# ## 2.1 ¿Qué es una variable?
#
# Una **variable** es un nombre que apunta a un valor en memoria.
#
# En Python:
# - no se declara el tipo explícitamente,
# - el tipo depende del valor asignado,
# - el tipo puede cambiar (pero no siempre es buena idea).
#
# Ejemplo:

# %%
edad = 21
print(edad)

edad = "21"
print(edad)
# Out:
# 21
# 21

# %% [markdown]
# ## 2.2 Tipos de datos básicos
#
# Los tipos más usados en ciencia de datos son:
#
# | Tipo | Ejemplo | Uso típico |
# |-----|--------|-----------|
# | `int` | `10` | conteos, cantidades |
# | `float` | `3.14` | promedios, medidas |
# | `bool` | `True`, `False` | condiciones |
# | `str` | `"Bogotá"` | categorías, texto |
# | `NoneType` | `None` | valores faltantes |

# %%
a = 10
b = 3.5
c = True
d = "Datos"
e = None

print(type(a), type(b), type(c), type(d), type(e))
# Out:
# <class 'int'> <class 'float'> <class 'bool'> <class 'str'> <class 'NoneType'>

# %% [markdown]
# ## 2.3 `type()` como herramienta de diagnóstico
#
# En análisis de datos, `type()` es una de las primeras herramientas
# para **detectar problemas en los datos**.

# %%
precio = "2500"
cantidad = 4

print(type(precio))
print(type(cantidad))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Error común: operar strings como números

# %%
precio * cantidad
# Out:
# '2500250025002500'

# %% [markdown]
# ## 2.4 Conversión de tipos (casting)
#
# Python permite convertir entre tipos cuando tiene sentido:
#
# - `int()`
# - `float()`
# - `str()`
# - `bool()`

# %%
precio = int(precio) # Conversión a entero
total = precio * cantidad
print("Total:", total)
# Out:
# Total: 10000

# %% [markdown]
# ## 2.5 El tipo `bool`
#
# `bool` solo puede tomar dos valores:
#
# - `True`
# - `False`
#
# Es el tipo base de todas las condiciones (`if`).

# %%
edad = 18

print(edad >= 18)
print(edad < 18)
# Out:
# True
# False

# %% [markdown]
# ### Conversión a `bool` (cuidado)
#
# En Python:
# - `0`, `""`, `None` → `False`
# - casi todo lo demás → `True`

# %%
bool(0), bool(1), bool(""), bool("A"), bool(None)
# Out:
# (False, True, False, True, False)

# %% [markdown]
# ## 2.6 Valores faltantes y `None`
#
# En datos reales, los valores faltantes existen.
#
# En Python se representan como:
# - `None`
#
# ⚠️ `None` **no es** lo mismo que `0` o `""`.

# %%
edad = None

print(edad)
print(type(edad))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# ### Comparaciones con `None`
#
# Nunca se debe comparar `None` con números directamente.

# %%
# Quitar comentarios y correr para probar
# edad > 18
# edad is None

# %% [markdown]
# ## 2.7 Buenas prácticas para nombres de variables
#
#
# ✔️ Usar nombres descriptivos
#
# ✔️ Todo en minúscula y separados por guion bajo
#
# ✔️ Evitar letras sueltas (`x`, `y`) en análisis reales
#
# Ejemplos correctos:
# - `edad_promedio`
# - `total_ventas`
# - `numero_contratos`

# %%
# Ejemplo confuso:
x = 1000
y = 0.19

total = x * y
print(total)

# Ejemplo claro:
valor_total_ventas = 1000
tasa_iva = 0.19

total_con_iva = valor_total_ventas * tasa_iva
print(total_con_iva)
# Out:
# 190.0
# 190.0

# %% [markdown]
# ## 2.8 Mini-ejercicio
#
# 1. Define una variable `precio_unitario` como string `"3500"`.
# 2. Define una variable `cantidad` como entero `3`.
# 3. Convierte `precio_unitario` a entero.
# 4. Calcula el total.
# 5. Verifica el tipo del resultado con `type()`.

# %%
# Desarrollo mini-ejercicio 2.8

# %% [markdown]
# # 3. Strings para limpieza básica de datos
#
# En ciencia de datos, **la limpieza de texto es una de las tareas más frecuentes**.
#
# Problemas comunes en datos reales:
# - espacios al inicio o final,
# - mayúsculas y minúsculas inconsistentes,
# - categorías escritas de distintas formas,
# - textos largos difíciles de interpretar.
#
# Antes de usar pandas o modelos, debemos **limpiar los strings**.

# %% [markdown]
# ## 3.1 ¿Qué es un string?
#
# Un **string** (`str`) es una secuencia de caracteres.
#
# En Python:
# - se define con comillas simples `' '` o dobles `" "`,
# - es **inmutable** (no se modifica, se crea uno nuevo),
# - se puede indexar y recorrer.

# %%
ciudad = " Bogotá "
print(ciudad)
print(type(ciudad))
# Out:
#  Bogotá
# <class 'str'>

# %% [markdown]
# ## 3.2 Indexación y slicing
#
# Cada carácter de un string tiene una posición (índice).
#
# - El primer carácter está en la posición `0`.
# - El último carácter puede accederse con `-1`.

# %%
texto = "Ciencia de Datos"

print(texto[0])
print(texto[1])
print(texto[-1])
# Out:
# C
# i
# s

# %%
print(texto[0:7]) # Extrae los primeros 7 caracteres
print(texto[:7])  # Extrae los primeros 7 caracteres (la posición inicial se puede omitir)
print(texto[11:]) # Extrae desde la posición 11 en adelante
# Out:
# Ciencia
# Ciencia
# Datos

# %% [markdown]
# ### Inmutabilidad de los strings
#
# Los strings **no se modifican en el lugar**.
#
# Esto genera muchos errores de principiantes.

# %%
nombre = "ana"
nombre.upper()
print(nombre)
# Out:
# ana

# %%
nombre = nombre.upper()
print(nombre)
# Out:
# ANA

# %% [markdown]
# ## 3.3 Métodos esenciales para limpieza de texto
#
# Los métodos más usados en ciencia de datos son:
#
# | Método | ¿Para qué sirve? |
# |------|------------------|
# | `.strip()` | quitar espacios |
# | `.lower()` | pasar a minúsculas |
# | `.upper()` | pasar a mayúsculas |
# | `.title()` | formato título |
# | `.replace()` | reemplazar texto |
# | `.split()` | separar texto |
# | `.join()` | unir texto |

# %%
# Quitar espacios al inicio y final de la cadena
ciudad = "  Medellín  "
ciudad_limpia = ciudad.strip()

print(f"Original: '{ciudad}'")
print(f"Limpia:   '{ciudad_limpia}'")
# Out:
# Original: '  Medellín  '
# Limpia:   'Medellín'

# %%
categoria = "  bOGotA  "

print(categoria.lower())
print(categoria.upper())
print(categoria.strip().title())
# Out:
#   bogota
#   BOGOTA
# Bogota

# %% [markdown]
# ### Normalización de categorías
#
# En análisis de datos, normalmente:
# - se pasa todo a minúsculas o mayúsculas,
# - luego se compara o agrupa.
#
# Esto evita tratar `"Bogotá"` y `"bogota"` como categorías distintas.

# %%
ciudades = ["Bogotá", " bogota ", "BOGOTA", "Medellín", " medellín"]

ciudades_limpias = []
for c in ciudades:
    ciudades_limpias.append(c.strip().lower())

ciudades_limpias
# Out:
# ['bogotá', 'bogota', 'bogota', 'medellín', 'medellín']

# %% [markdown]
# ## 3.4 Reemplazo de texto con `.replace()`
#
# Permite corregir errores frecuentes o unificar formatos.

# %%
texto = "No aplica / N.A. / no aplica"
texto_limpio = texto.replace("N.A.", "No aplica")
texto_limpio = texto_limpio.upper()
texto_limpio
# Out:
# 'NO APLICA / NO APLICA / NO APLICA'

# %% [markdown]
# ## 3.5 Separar texto con `.split()`
#
# Convierte un string en una lista.

# %%
frase = "Ciencia de datos con Python"
palabras = frase.split()

palabras
# Out:
# ['Ciencia', 'de', 'datos', 'con', 'Python']

# %% [markdown]
# ## 3.6 Unir texto con `.join()`
#
# Hace el proceso inverso: unir una lista en un string.

# %%
palabras = ["ciencia", "de", "datos"]
frase = " ".join(palabras)

frase
# Out:
# 'ciencia de datos'

# %%
palabras = ["ciencia", "de", "datos"]
frase = "_".join(palabras)

frase
# Out:
# 'ciencia_de_datos'

# %% [markdown]
# ## 3.7 f-strings para reportes de resultados
#
# Los **f-strings** permiten construir textos claros y legibles
# para reportes y salidas finales.

# %%
ciudad = "bogota"
total_contratos = 125
promedio_valor = 3.75

print(f"En la ciudad de {ciudad.title()} se analizaron {total_contratos} contratos.")
print(f"El valor promedio fue de {promedio_valor:.2f} millones.")
# Out:
# En la ciudad de Bogota se analizaron 125 contratos.
# El valor promedio fue de 3.75 millones.

# %% [markdown]
# ## 3.8 Mini-ejercicio
#
# Dada la siguiente lista:
#
# ```python
# nombres = [" ana ", "LUIS", " María", "carlos "]
# ```
#
# 1. Elimina espacios.
# 2. Convierte todo a formato título.
# 3. Guarda el resultado en una nueva lista nombres_limpios.

# %%
# Desarrollo mini-ejercicio 3.8

# %% [markdown]
# # 4. Estructuras de datos esenciales en Python
#
# En ciencia de datos, casi toda la información se representa usando
# **estructuras de datos**.
#
# Antes de usar pandas o bases de datos, debemos entender cómo manejar:
#
# - listas,
# - tuplas,
# - diccionarios,
# - conjuntos (sets).
#
# Estas estructuras son la base de:
# - tablas,
# - archivos JSON,
# - respuestas de APIs,
# - resultados de modelos.

# %% [markdown]
# ## 4.1 Listas (`list`)
#
# Una **lista** es una colección ordenada de elementos.
#
# Características:
# - pueden contener distintos tipos,
# - mantienen el orden,
# - se pueden modificar (son mutables).

# %%
edades = [21, 19, 20, 22]
ciudades = ["Bogotá", "Medellín", "Cali"]

print(edades)
print(ciudades)
# Out:
# [21, 19, 20, 22]
# ['Bogotá', 'Medellín', 'Cali']

# %% [markdown]
# ### Indexación y slicing
#
# Las listas se indexan igual que los strings.

# %%
print(edades[0])
print(edades[-1])
print(edades[1:3])
# Out:
# 21
# 22
# [19, 20]

# %% [markdown]
# ### Modificar listas
#
# Las listas permiten:
# - agregar elementos,
# - modificar valores existentes.

# %%
print(edades)

# Agregar un valor en la última posición
edades.append(23)
print(edades)

# Modifica el valor de la posición cero de la lista
edades[0] = 22
print(edades)
# Out:
# [22, 19, 20, 22, 23, 23, 23, 23, 23]
# [22, 19, 20, 22, 23, 23, 23, 23, 23, 23]
# [22, 19, 20, 22, 23, 23, 23, 23, 23, 23]

# %% [markdown]
# ## 4.2 Tuplas (`tuple`)
#
# Una **tupla** es una colección ordenada **inmutable**.
#
# Se usan cuando:
# - los valores no deben cambiar,
# - queremos retornar varios valores desde una función.

# %%
coordenadas = (4.7110, -74.0721)
print(coordenadas)
# Out:
# (4.711, -74.0721)

# %% [markdown]
# Las tuplas **no pueden modificarse**.

# %%
# Quitar el comentario y correr celda
# coordenadas[0] = 5.0

# %% [markdown]
# ## 4.3 Diccionarios (`dict`)
#
# Un **diccionario** almacena pares `clave : valor`.
#
# Es la estructura más importante en ciencia de datos porque:
# - representa registros (filas),
# - es la base de JSON,
# - permite acceso rápido por clave.

# %%
persona = {
    "nombre": "Ana",
    "edad": 21,
    "ciudad": "Bogotá"
}

persona
# Out:
# {'nombre': 'Ana', 'edad': 21, 'ciudad': 'Bogotá'}

# %% [markdown]
# ### Acceso a valores en diccionarios
#
# Para acceder a la información de los diccionarios se deben usar las claves (keys)

# %%
persona.keys()
# Out:
# dict_keys(['nombre', 'edad', 'ciudad'])

# %%
persona.values()
# Out:
# dict_values(['Ana', 21, 'Bogotá'])

# %%
print(persona["nombre"])
print(persona["edad"])
# Out:
# Ana
# 21

# %% [markdown]
# ⚠️ Error común: acceder a una clave que no existe.

# %%
# Quitar comentario y correr celda
# persona["telefono"]

# %%
# Forma segura:
print(persona.get("nombre"))
print(persona.get("edad"))
print(persona.get("ciudad"))
print(persona.get("telefono"))
# Out:
# Ana
# 21
# Bogotá
# None

# %% [markdown]
# ### Modificar y agregar información

# %%
persona["edad"] = 22
persona["telefono"] = 3001234567

persona
# Out:
# {'nombre': 'Ana', 'edad': 22, 'ciudad': 'Bogotá', 'telefono': 3001234567}

# %% [markdown]
# ### Iterar sobre diccionarios
#
# Iterar sobre diccionarios es muy común en análisis de datos.

# %%
for clave, valor in persona.items():
    print(clave, "->", valor)
# Out:
# nombre -> Ana
# edad -> 22
# ciudad -> Bogotá
# telefono -> 3001234567

# %% [markdown]
# ## 4.4 Lista de diccionarios (estructura tipo tabla)
#
# Una forma muy común de representar datos es:
#
# - cada diccionario = una fila,
# - cada clave = una columna.

# %%
datos = [
    {"nombre": "Ana", "edad": 21, "ciudad": "Bogotá"},
    {"nombre": "Luis", "edad": 19, "ciudad": "Medellín"},
    {"nombre": "María", "edad": 20, "ciudad": "Cali"},
]

datos
# Out:
# [{'nombre': 'Ana', 'edad': 21, 'ciudad': 'Bogotá'},
#  {'nombre': 'Luis', 'edad': 19, 'ciudad': 'Medellín'},
#  {'nombre': 'María', 'edad': 20, 'ciudad': 'Cali'}]

# %% [markdown]
# ## 4.5 Sets (`set`)
#
# Un **set** es una colección:
# - sin orden,
# - sin elementos duplicados.
#
# Se usan para:
# - eliminar duplicados,
# - verificar pertenencia.

# %%
ciudades = ["Bogotá", "Bogotá", "Cali", "Medellín", "Cali"]
ciudades_unicas = set(ciudades)

ciudades_unicas
# Out:
# {'Bogotá', 'Cali', 'Medellín'}

# %% [markdown]
# ### Verificar pertenencia

# %%
"Bucaramanga" in ciudades_unicas
# Out:
# False

# %% [markdown]
# ## 4.6 Mini-ejercicio integrador
#
# Dada la siguiente estructura:
#
# ```python
# ventas = [
#     {"ciudad": "bogota", "valor": 1200},
#     {"ciudad": " medellin", "valor": 800},
#     {"ciudad": "Bogota", "valor": 1500},
#     {"ciudad": "cali ", "valor": "500"},
#     {"ciudad": "Cali", "valor": 678},
#     {"ciudad": "Medellin", "valor": 900},
# ]
# ```
#
# 1. Limpiar los datos.
# 1. Obtén las ciudades únicas.
# 2. Calcula el total de ventas por ciudad.
# 3. Guarda el resultado en un diccionario.

# %%
# Solución Miniejercicio 4.6
ventas = [
    {"ciudad": "bogota", "valor": 1200},
    {"ciudad": " medellin", "valor": 800},
    {"ciudad": "Bogota", "valor": 1500},
    {"ciudad": "cali ", "valor": "500"},
    {"ciudad": "Cali", "valor": 678},
    {"ciudad": "Medellin", "valor": 900},
]
ventas
# Out:
# [{'ciudad': 'bogota', 'valor': 1200},
#  {'ciudad': ' medellin', 'valor': 800},
#  {'ciudad': 'Bogota', 'valor': 1500},
#  {'ciudad': 'cali ', 'valor': '500'},
#  {'ciudad': 'Cali', 'valor': 678},
#  {'ciudad': 'Medellin', 'valor': 900}]

# %% [markdown]
# # 5. Control de flujo aplicado a datos
#
# En ciencia de datos, el **control de flujo** permite:
#
# - filtrar observaciones,
# - validar datos,
# - aplicar reglas de negocio,
# - construir métricas y resúmenes.
#
# Las estructuras más importantes son:
# - `if / elif / else`
# - `for`
# - (en casos puntuales) `while`

# %% [markdown]
# ## 5.1 Condicionales (`if`, `elif`, `else`)
#
# Las condiciones permiten **tomar decisiones** según el valor de los datos.

# %%
edad = 20

if edad >= 18:
    print("Mayor de edad")
else:
    print("Menor de edad")
# Out:
# Mayor de edad

# %% [markdown]
# ### Condiciones con datos reales
#
# En datos reales:
# - puede haber valores faltantes,
# - puede haber tipos incorrectos.
#
# Siempre debemos validar antes de comparar.

# %%
edad = None

if edad is None:
    print("Edad no reportada")
elif edad >= 18:
    print("Mayor de edad")
else:
    print("Menor de edad")
# Out:
# Edad no reportada

# %% [markdown]
# ## Error común: confundir `=` con `==`

# %%
# Esto produce error
# if edad = 18:
#    print("Edad es 18")

# %% [markdown]
# ## 5.2 Operadores de comparación y lógicos
#
# - Comparación: `==`, `!=`, `<`, `<=`, `>`, `>=`
# - Lógicos: `and`, `or`, `not`

# %%
edad = 20
ciudad = "Bogotá"

if edad >= 18 and ciudad == "Bogotá":
    print("Cumple condiciones")
# Out:
# Cumple condiciones

# %% [markdown]
# ## 5.3 Bucles `for`
#
# Los bucles permiten **recorrer colecciones de datos**.

# %%
edades = [21, 19, 20, 22]

for e in edades:
    print(e)
# Out:
# 21
# 19
# 20
# 22

# %% [markdown]
# ### Filtrado de datos con `for + if`

# %%
mayores = []

for e in edades:
    if e >= 21:
        mayores.append(e)

mayores
# Out:
# [21, 22]

# %% [markdown]
# ## 5.4 Recorrer diccionarios
#
# Muy común para construir resúmenes.

# %%
persona = {"nombre": "Ana", "edad": 21, "ciudad": "Bogotá"}

for clave, valor in persona.items():
    print(clave, "→", valor)
# Out:
# nombre → Ana
# edad → 21
# ciudad → Bogotá

# %% [markdown]
# ## 5.5 Acumuladores (patrón clave)
#
# Un patrón común en ciencia de datos es:
# - iniciar una variable,
# - actualizarla dentro de un bucle.

# %%
valores = [1200, 800, 1500]

total = 0
for v in valores:
    total += v

total
# Out:
# 3500

# %% [markdown]
# ### Conteos por categoría

# %%
ciudades = ["bogota", "medellin", "bogota", "cali", "bogota"]

conteo = {}

for c in ciudades:
    conteo[c] = conteo.get(c, 0) + 1

conteo
# Out:
# {'bogota': 3, 'medellin': 1, 'cali': 1}

# %% [markdown]
# ## 5.6 `enumerate`
#
# `enumerate` permite acceder al índice y al valor al mismo tiempo.

# %%
nombres = ["Ana", "Luis", "María"]

for i, nombre in enumerate(nombres):
    print(i, nombre)
# Out:
# 0 Ana
# 1 Luis
# 2 María

# %% [markdown]
# ## 5.7 `zip`
#
# `zip` permite recorrer varias listas al mismo tiempo.

# %%
nombres = ["Ana", "Luis", "María"]
edades = [21, 19, 20]

for nombre, edad in zip(nombres, edades):
    print(nombre, edad)
# Out:
# Ana 21
# Luis 19
# María 20

# %% [markdown]
# ## 5.8 Bucle `while`
#
# El `while` se usa cuando:
# - no sabemos cuántas iteraciones habrá,
# - depende de una condición.

# %%
contador = 0

while contador < 3:
    print("Iteración", contador)
    contador += 1
# Out:
# Iteración 0
# Iteración 1
# Iteración 2

# %% [markdown]
# ## 5.9 Mini-ejercicio integrador
#
# Dada la siguiente estructura:
#
# ```python
# contratos = [
#     {"valor": 1200, "estado": "ejecutado"},
#     {"valor": 800, "estado": "cancelado"},
#     {"valor": 1500, "estado": "ejecutado"},
# ]
# ```
#
# 1. Suma el valor total de los contratos ejecutados.
# 2. Cuenta cuántos contratos no están ejecutados.
# 3. Guarda los resultados en variables claras.

# %% [markdown]
# # 6. Funciones en Python para Ciencia de Datos
#
# En ciencia de datos, **las funciones son esenciales** para:
#
# - evitar repetir código,
# - estructurar análisis largos,
# - documentar lógica de negocio,
# - hacer el código más legible y mantenible.
#
# Un análisis serio **no puede ser solo una secuencia de celdas largas**.

# %% [markdown]
# ## 6.1 ¿Qué es una función?
#
# Una **función** es un bloque de código que:
#
# - recibe entradas (parámetros),
# - ejecuta una tarea,
# - devuelve un resultado (`return`).
#
# Una vez definida, puede reutilizarse muchas veces.

# %%
def saludar():
    print("Hola desde una función")

saludar()
# Out:
# Hola desde una función

# %% [markdown]
# ## 6.2 Funciones con parámetros
#
# Las funciones pueden recibir información de entrada.

# %%
def saludar_persona(nombre):
    print(f"Hola {nombre}")

saludar_persona("Ana")
saludar_persona("Luis")
# Out:
# Hola Ana
# Hola Luis

# %% [markdown]
# ## 6.3 `return`: devolver resultados
#
# En ciencia de datos, casi siempre queremos que
# las funciones **devuelvan resultados**, no solo impriman.

# %%
def calcular_total(precio, cantidad):
    total = precio * cantidad
    return total

resultado = calcular_total(3500, 3)
resultado
# Out:
# 10500

# %% [markdown]
# ## 6.4 Funciones puras (buena práctica)
#
# Una **función pura**:
# - depende solo de sus argumentos,
# - no modifica variables externas,
# - siempre produce el mismo resultado con los mismos inputs.
#
# Este tipo de funciones es ideal para análisis reproducibles.

# %%
def promedio(valores):
    return sum(valores) / len(valores)

promedio([10, 20, 30])
# Out:
# 20.0

# %% [markdown]
# ## 6.5 Argumentos por defecto
#
# Permiten definir valores “por defecto” para parámetros opcionales.

# %%
def aplicar_iva(valor, tasa=0.19):
    return valor * (1 + tasa)

print(aplicar_iva(1000))
print(aplicar_iva(1000, 0.05))
# Out:
# 1190.0
# 1050.0

# %% [markdown]
# ## 6.6 Validación de datos dentro de funciones
#
# En ciencia de datos, una función **debe validar sus entradas**.

# %%
def promedio_seguro(valores):
    if not valores:
        return None
    return sum(valores) / len(valores)

print(promedio_seguro([]))
print(promedio_seguro([10, 20, 30]))
# Out:
# None
# 20.0

# %% [markdown]
# ## 6.7 Documentar funciones con docstrings
#
# Las **docstrings** explican:
# - qué hace la función,
# - qué recibe,
# - qué devuelve.
#
# Son esenciales en proyectos reales.

# %%
def limpiar_texto(texto):
    """
    Limpia un texto eliminando espacios y normalizando a minúsculas.

    Parámetros
    ----------
    texto : str
        Texto de entrada.

    Retorna
    -------
    str
        Texto limpio.
    """
    return texto.strip().lower()

limpiar_texto("  BogotÁ ")
# Out:
# 'bogotá'

# %%
help(limpiar_texto)
# Out:
# Help on function limpiar_texto in module __main__:
#
# limpiar_texto(texto)
#     Limpia un texto eliminando espacios y normalizando a minúsculas.
#
#     Parámetros
#     ----------
#     texto : str
#         Texto de entrada.
#
#     Retorna
#     -------
#     str
#         Texto limpio.

# %% [markdown]
# ## 6.8 Retornar múltiples valores
#
# Python permite retornar varios valores usando tuplas.

# %%
def resumen_numerico(valores):
    return min(valores), max(valores), sum(valores) / len(valores)

minimo, maximo, promedio = resumen_numerico([10, 20, 30])
minimo, maximo, promedio
# Out:
# (10, 30, 20.0)

# %% [markdown]
# ## 6.9 Mini-ejercicio integrador
#
# Crea una función llamada `total_por_ciudad` que:
#
# 1. Reciba una lista de diccionarios con claves `"ciudad"` y `"valor"`.
# 2. Calcule el total de valores por ciudad.
# 3. Retorne un diccionario con el resultado.
#
# *Pista: usa un diccionario acumulador.*

# %% [markdown]
# # 7. Pythonic tools: built-ins y comprehensions
#
# Python ofrece muchas herramientas **integradas (built-ins)** que permiten
# resolver problemas comunes de ciencia de datos con **menos código y mayor claridad**.
#
# Usar estas herramientas:
# - hace el código más legible,
# - reduce errores,
# - facilita el paso a pandas y NumPy.

# %% [markdown]
# ## 7.1 Built-ins más usados en ciencia de datos
#
# Algunas funciones integradas de Python que usarás constantemente:
#
# - `len()` → tamaño de una colección (lista, diccionario, tupla, set)
# - `sum()` → suma de valores
# - `min()`, `max()` → extremos
# - `sorted()` → ordenar
# - `any()`, `all()` → validaciones lógicas

# %%
valores = [10, 20, 30, 40]

len(valores), sum(valores), min(valores), max(valores)
# Out:
# (4, 100, 10, 40)

# %% [markdown]
# ## 7.2 Ordenar datos con `sorted()`
#
# `sorted()` **no modifica** la lista original.

# %%
valores = [30, 10, 40, 20]

ordenados = sorted(valores)
valores, ordenados
# Out:
# ([30, 10, 40, 20], [10, 20, 30, 40])

# %% [markdown]
# ## 7.3 Validaciones con `any()` y `all()`
#
# Muy útiles para verificar reglas sobre los datos.

# %%
edades = [21, 19, 20, 22]

print(any(e < 18 for e in edades))   # ¿hay algún menor de edad?
print(all(e >= 18 for e in edades))  # ¿todos son mayores de edad?
# Out:
# False
# True

# %% [markdown]
# ## 7.4 List comprehensions
#
# Las **list comprehensions** permiten crear listas de forma compacta.
#
# Sintaxis general:
#
# ```python
# [nueva_expresión for elemento in colección if condición]

# %%
potencias = [x**2 for x in range(10)]
potencias
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
edades = [21, 19, 20, 22]

mayores = [e for e in edades if e >= 21]
mayores
# Out:
# [21, 22]

# %% [markdown]
# ## 7.5 Comprensiones con strings
#
# Muy comunes en limpieza de texto.

# %%
# p1:p10
["p" + str(i) for i in range(1, 11)]
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10']

# %%
nombres = [" ana ", "LUIS", " María", "carlos "]

nombres_limpios = [n.strip().title() for n in nombres]
nombres_limpios
# Out:
# ['Ana', 'Luis', 'María', 'Carlos']

# %% [markdown]
# ## 7.6 Dict comprehensions
#
# Permiten crear diccionarios de forma compacta.

# %%
ventas = [
    {"ciudad": "bogota", "valor": 1200},
    {"ciudad": "medellin", "valor": 800},
    {"ciudad": "bogota", "valor": 1500},
]

totales = {}

for v in ventas:
    ciudad = v["ciudad"]
    totales[ciudad] = totales.get(ciudad, 0) + v["valor"]

totales
# Out:
# {'bogota': 2700, 'medellin': 800}

# %%
totales = {
    ciudad: sum(v["valor"] for v in ventas if v["ciudad"] == ciudad)
    for ciudad in set(v["ciudad"] for v in ventas)
}

totales
# Out:
# {'medellin': 800, 'bogota': 2700}

# %% [markdown]
# ## 7.7 ¿Cuándo NO usar comprehensions?
#
# No todo debe ser una comprehension.
#
# Evita comprehensions cuando:
# - la lógica es muy compleja,
# - hay muchas condiciones,
# - afecta la legibilidad.
#
# La **claridad** es más importante que escribir menos líneas.

# %% [markdown]
# ## 7.8 Mini-ejercicio integrador
#
# Dada la siguiente lista:
#
# ```python
# valores = [1200, 800, 1500, 500, 2000]
# ```
#
# 1. Calcula el promedio usando `sum()` y `len()`.
# 2. Crea una lista con los valores mayores al promedio usando comprehension.
# 3. Verifica con `all()` si todos los valores son mayores a 0.

# %% [markdown]
# # 8. Mini-caso integrador: Análisis exploratorio básico con Python
#
# En esta sección integraremos todo lo aprendido hasta ahora para realizar
# un **análisis exploratorio básico**, usando únicamente Python base
# (sin pandas ni NumPy).
#
# El objetivo es que comprendas **qué hace pandas por debajo** antes de usarlo.

# %% [markdown]
# ## Contexto
#
# Se cuenta con información simplificada de **contratos de obra pública**
# registrados por diferentes municipios.
#
# Cada contrato tiene:
# - un identificador,
# - un municipio,
# - un valor del contrato,
# - un estado del contrato.
#
# ⚠️ Los datos **no están limpios** y presentan problemas típicos del mundo real.

# %%
contratos = [
    {"id": "C001", "municipio": " bogota ", "valor": "1200000", "estado": "EJECUTADO"},
    {"id": "C002", "municipio": "Bogotá", "valor": "800000", "estado": "cancelado"},
    {"id": "C003", "municipio": "MEDELLIN", "valor": "1500000", "estado": "ejecutado"},
    {"id": "C004", "municipio": " bogota", "valor": "950000", "estado": "EJECUTADO"},
    {"id": "C005", "municipio": "Medellín ", "valor": "1100000", "estado": "ejecutado"},
]

# %% [markdown]
# ## Objetivos analíticos
#
# 1. Limpiar y normalizar los datos.
# 2. Convertir los tipos de datos correctamente.
# 3. Filtrar contratos ejecutados.
# 4. Calcular métricas descriptivas básicas.
# 5. Generar un resumen analítico legible.
#
# Este flujo es equivalente a un **EDA inicial**.

# %% [markdown]
# ## Paso 1: Limpieza y normalización de los datos
#
# Tareas:
# - normalizar el nombre del municipio,
# - convertir el valor a numérico,
# - normalizar el estado del contrato.

# %%
# Paso 1.

# %% [markdown]
# ## Paso 2: Validación rápida
#
# Verificamos:
# - tipos de datos,
# - valores faltantes,
# - estructura general.

# %%
# Paso 2.

# %% [markdown]
# ## Paso 3: Filtrado analítico
#
# Nos enfocamos únicamente en contratos **ejecutados**.

# %%
# Paso 3.

# %% [markdown]
# ## Paso 4: Métricas descriptivas básicas
#
# Calcularemos:
# - número de contratos ejecutados,
# - valor total ejecutado,
# - valor promedio por contrato.

# %%
# Paso 4

# %% [markdown]
# ## Paso 5: Análisis por municipio
#
# Calcularemos el valor total ejecutado por municipio.

# %%
# Paso 5.

# %% [markdown]
# ## Paso 6: Resumen analítico
#
# Presentamos los resultados en formato legible para un reporte.

# %%
# Paso 6.
