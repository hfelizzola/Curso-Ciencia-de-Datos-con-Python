# %% [markdown]
# <a href="https://colab.research.google.com/github/hfelizzola/Curso-Ciencia-de-Datos-con-Python/blob/main/2_numpy_pandas_limpieza_datos/2_numpy_pandas_ciencia_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 3. NumPy y Pandas para Ciencia de Datos (básico–intermedio)
#
# **Curso:** Ciencia de Datos con Python
# **Semana:** 3
# **Tema:** NumPy y Pandas — limpieza, procesamiento y análisis
# **Modalidad:** Notebook (teoría + práctica guiada)

# %% [markdown]
# ---
# ## ¿Qué aprenderás hoy?
#
# Al finalizar este notebook podrás:
#
# 1. Crear y manipular **arrays** de NumPy, usando operaciones **vectorizadas** y **máscaras booleanas**.
# 2. Calcular estadísticas y manejar valores faltantes numéricos con funciones tipo `nan*`.
# 3. Cargar datos tabulares en **pandas** (`DataFrame`) y hacer una inspección rápida.
# 4. Limpiar datos: faltantes, duplicados, tipos, texto sucio y fechas.
# 5. Transformar datos: crear variables, segmentar con `cut/qcut`.
# 6. Resumir y analizar: `groupby`, `agg`, `pivot_table`, y ordenamiento.
# 7. Integrar tablas con `merge` y apilar con `concat`.
#
# ---
#
# ## Prerrequisitos
#
# - Fundamentos de python: variables y tipos de datos
# - Estructuras de datos listas/diccionarios
# - Control de flujos `if`, `for`, funciones.
# - Funciones de python
#
#
#
# ---
#
# ## Agenda
#
# 1. Configuración y reproducibilidad
# 2. NumPy: arrays, vectorización e indexación
# 3. NumPy: estadísticas, NaNs y reshape
# 4. Pandas: cargar, inspeccionar, seleccionar
# 5. Pandas: limpieza (missing, duplicados, tipos, texto, fechas)
# 6. Pandas: transformación y análisis (groupby, pivot)
# 7. Integración de datos (merge/concat)
# 8. Mini-reto integrador
#
# ---
#
# ## Reglas de trabajo (importante)
#
# - Ejecuta las celdas **en orden** (de arriba hacia abajo).
# - En los ejercicios: intenta tú primero; luego revisa la solución si se incluye.
# - Si algo sale raro: **Entorno de ejecución → Reiniciar sesión y ejecutar todo**.

# %%
# =========================================
# 1. Configuración del notebook
# =========================================

import numpy as np
import pandas as pd

# Para reproducibilidad
np.random.seed(42)

# Opciones visuales de pandas (solo para comodidad en clase)
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

print("✅ Librerías importadas. Versión NumPy:", np.__version__, "| Versión pandas:", pd.__version__)

# %%
# Conectar con drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Configurar el directorio de trabajo en colab: "/content/drive/MyDrive/Colab Notebooks"
import os
#os.chdir("/content/drive/MyDrive/Colab Notebooks")
os.chdir("/content/drive/MyDrive/Colab Notebooks/Ciencia de Datos con Python")
# Verificar lista de archivos
# !ls

# %% [markdown]
# # 2. NumPy: el motor numérico
#
# NumPy trabaja con el objeto principal **`ndarray`** (array N-dimensional).
#
# ¿Por qué es clave en Ciencia de Datos?
#
# - Es **rápido** (vectorización en C).
# - Permite operaciones matemáticas sobre grandes volúmenes de datos.
# - Es la base de muchas librerías (pandas, scikit-learn, etc.).
#
# En esta sección veremos funciones y patrones más usados.

# %% [markdown]
# ## 2.1 Crear arrays
#
# Funciones típicas:
#
# - `np.array(...)`: crea un array desde una lista.
# - `np.arange(inicio, fin, paso)`: rango (similar a `range`, pero devuelve array).
# - `np.linspace(inicio, fin, n)`: n puntos igualmente espaciados.
# - `np.zeros(n)`, `np.ones(n)`: inicializadores.
# - `np.random.*`: datos simulados.
#
# **Rol en ciencia de datos:** generar datos de ejemplo, crear estructuras numéricas, simular escenarios.

# %%
# Crear arrays a partir de una lista
a = np.array([10, 20, 30, 40])
a

# %%
# Crear un array de 0 a 8 con incrementos de 2
b = np.arange(0, 10, 2)
b

# %%
# Crear un array de 0 - 1, con 5 valores igualmente espaciados
c = np.linspace(0, 1, 5)
c

# %%
# Crear un array de ceros, unos y valores aleatorios
z = np.zeros(4)
o = np.ones(4)
ru = np.random.random(size=4) # Distribución Uniforme
rn = np.random.normal(size=4) # Distribución Normal
z, o, ru, rn

# %% [markdown]
# ### 🧩 Tu turno (3–5 min)
#
# 1. Crea un array llamado `x` con valores del 1 al 12 usando `np.arange`.
# 2. Crea un array llamado `p` con 6 puntos entre 0 y 100 usando `np.linspace`.
# 3. Crea un array `ruido` de 12 números aleatorios normales con media 0 y desviación 1 (`np.random.normal`).
#
# > Pista: `np.random.normal(loc=0, scale=1, size=...)`

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 2.2 Vectorización y broadcasting
#
# **Vectorización** = aplicar operaciones a todo el array sin bucles explícitos.
#
# Ejemplos típicos:
# - Escalar: `x * 2`, `x + 10`
# - Funciones: `np.log(x)`, `np.sqrt(x)`
# - Comparaciones: `x > 5` (devuelve booleanos)
#
# **Broadcasting** = reglas para operar arrays con formas compatibles.
#
# **Rol en ciencia de datos:** acelerar transformaciones y cálculos.

# %%
x = np.arange(1, 13)

x2 = x * 2
x2

# %%
logx = np.log(x)
logx

# %%
mask = x > 6
mask

# %% [markdown]
# ## 2.3 Filtrado con máscaras booleanas
#
# Una máscara booleana te permite **seleccionar** elementos que cumplen una condición.
#
# Patrón común:
# ```python
# mask = x > 6
# x_filtrado = x[mask]
# ```
#
# **Rol:** limpiar outliers, filtrar registros, aplicar reglas de negocio.

# %%
x = np.arange(1, 13)
mask = (x >= 4) & (x <= 9)

x_filtrado = x[mask]
x_filtrado

# %% [markdown]
# ### 🧩 Tu turno (5–7 min)
#
# Con el array `x = np.arange(1, 31)`:
#
# 1. Selecciona los múltiplos de 3 (Use la operador de modulo de python `%`).
# 2. Selecciona los valores entre 10 y 20 (incluidos).
# 3. Reemplaza por 0 los valores mayores a 25 (sin usar `for`).
#
# > Pista 3: `x_mod = x.copy()` y luego indexación booleana.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 2.4 Estadísticos y agregaciones
#
# Funciones comunes:
#
# - `np.mean`, `np.median`, `np.std`
# - `np.min`, `np.max`, `np.sum`
# - `np.quantile` (cuantiles)
#
# Con faltantes `np.nan`, usa la familia:
# - `np.nanmean`, `np.nanmedian`, `np.nanstd`, etc.
#
# **Rol:** resumen rápido del comportamiento de variables numéricas.

# %%
y = np.array([10, 12, 11, np.nan, 9, 13, np.nan, 12])

# Estadísticos ignorando NaNs
media = np.nanmean(y)
mediana = np.nanmedian(y)
desv = np.nanstd(y)

media, mediana, desv

# %% [markdown]
# ## 2.5 `reshape`, `ravel` y `transpose`
#
# En ciencia de datos es común convertir datos entre forma "vector" y forma "matriz".
#
# - `reshape(r, c)`: cambia la forma (si el tamaño total coincide).
# - `ravel()`: aplana a 1D (vista cuando es posible).
# - `.T`: transpuesta.
#
# **Rol:** preparar datos para modelos y operaciones matriciales.

# %%
# Crear una matriz de 3 X 4
m = np.arange(1, 13).reshape(3, 4)
m

# %%
# Aplanar a un vector de una dimensión
m.ravel()

# %%
# Transponer
m.T

# %% [markdown]
# ### 🧩 Tu turno (4–6 min)
#
# 1. Crea una matriz `A` de tamaño (4, 3) con números del 1 al 12.
# 2. Obtén la **segunda columna** de `A`.
# 3. Calcula la suma y promedio. por filas y la suma por columnas.
#
# > Pista: `A[:, 1]`, operaciones por columna `A.sum(axis=0)`, operaciones por fila: `A.sum(axis=1)`.

# %%
# Escribe tu solución aquí

# %% [markdown]
# # 3. pandas: datos tabulares (DataFrame)
#
# pandas está diseñado para trabajar con datos tipo tabla (como Excel o SQL).
#
# Objeto principal: **`DataFrame`** (filas = observaciones, columnas = variables).
#
# En esta sección trabajaremos con un dataset pequeño **intencionalmente sucio** para practicar limpieza.

# %% [markdown]
# ## 3.1 Dataset de clase (intencionalmente sucio)
#
# Crearemos un dataset de ventas con problemas típicos:
#
# - valores faltantes
# - duplicados
# - columnas numéricas guardadas como texto (`"1,200"`, `"$ 35.000"`)
# - texto con espacios / mayúsculas inconsistentes
# - fechas en formatos mixtos
#
# > En proyectos reales estos problemas son MUY comunes.

# %%
# Cargar datos de ventas
df_raw = pd.read_csv("ventas.csv")

# Ver las primeras filas de la tabla
df_raw.head()

# %% [markdown]
# ## 3.2 Inspección rápida
#
# Funciones clave:
#
# - `.head()` / `.tail()`: primeras/últimas filas
# - `.shape`: (filas, columnas)
# - `.info()`: tipos, nulos y memoria
# - `.describe()`: estadísticos (numéricos por defecto)
# - `.value_counts()`: conteos de categorías
#
# **Rol:** diagnóstico inicial antes de limpiar o modelar.

# %%
# Numero de filas y columnas
df_raw.shape

# %%
# Información general de la tabla
df_raw.info()

# %% [markdown]
# ### 🧩 Tu turno (5 min)
#
# 1. Muestra las últimas 3 filas (`tail`).
# 2. Obtén los conteos de `canal` con `value_counts("col_name")`.
# 3. Usa `describe(include="all")` para ver un resumen más amplio.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 3.3 Selección: columnas, `loc` y `iloc`
#
# - Selección por columna: `df["col"]` o `df[["col1","col2"]]`
# - Selección por posición: `df.iloc[filas, cols]`
# - Selección por etiqueta (si hay índice): `df.loc[filas, cols]`
#
# **Rol:** construir subconjuntos para análisis y para reglas de limpieza.

# %%
# Columnas específicas
df_raw[["fecha", "ciudad", "producto", "unidades"]].head()

# %%
# iloc: filas 0-2 y columnas 0-3
df_raw.iloc[0:3, 0:4]

# %% [markdown]
# # 4. Limpieza de datos con pandas
#
# Vamos a construir un `df` limpio paso a paso, aplicando operaciones comunes:
#
# 1. Normalizar texto (`str.strip`, `str.lower`, reemplazos)
# 2. Convertir tipos (`to_datetime`, `to_numeric`)
# 3. Manejar faltantes (`isna`, `fillna`, `dropna`)
# 4. Eliminar duplicados (`drop_duplicates`)
#
# > **Buenas práctica:** no sobreescribir el dataset original; crea una copia.

# %% [markdown]
# ## 4.1 Copia de trabajo y normalización de texto
#
# Funciones clave:
# - `df.copy()`: copia segura
# - `.str.strip()`: quitar espacios
# - `.str.lower()` / `.str.upper()` / `.str.title()`
# - `.replace(...)`: mapear categorías inconsistentes
#
# **Rol:** homogeneizar variables categóricas para que sean analizables.

# %%
# Crear una copia
df = df_raw.copy()

# %%
# Revisar valores únicos y posibles errores
df["ciudad"].unique()

# %%
# Normalización de texto: ciudad
df["ciudad"] = df["ciudad"].astype("string").str.strip()

# %%
# Normalización de texto: canal
df["canal"] = df["canal"].astype("string").str.strip().str.lower()

# %%
# Unificar "Bogotá" / "Bogota" (y variantes por espacios)
df["ciudad"] = (df["ciudad"]
                .str.replace("Bogota", "Bogotá", regex=False)
                .str.replace("bogota", "Bogotá", regex=False)
               )

df[["ciudad", "canal"]].head(10)

# %% [markdown]
# ### 🧩 Tu turno (6–8 min)
#
# 1. Normaliza `producto`: quita espacios y ponlo en minúscula.
# 2. Normaliza `cliente`: quita espacios al inicio/fin y ponlo en formato *Title Case* (`str.title()`).
# 3. Termina de normalizar `ciudad`: unifica el nombre de todas las ciudades y ponlo en formato *Title Case*
# 4. Revisa los valores únicos (`unique`) de `producto` y `canal` después de limpiar.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 4.2 Convertir fechas (formatos mixtos)
#
# Usaremos `pd.to_datetime` con `errors="coerce"`:
# - Si una fecha no se puede convertir, queda como `NaT` (faltante de fecha).
#
# **Rol:** estandarizar fechas para series de tiempo, filtros por periodo, y reportes.

# %%
df["fecha"]

# %%
df["fecha_dt"] = pd.to_datetime(df["fecha"], errors="coerce", dayfirst=True)

df[["fecha", "fecha_dt"]]

# %% [markdown]
# ## 4.3 Convertir números que vienen como texto
#
# Problema típico: `"$ 35.000"` o `"120.000"`.
#
# Estrategia:
# 1. Limpiar símbolos (`$`, espacios)
# 2. Quitar separadores de miles (`.` o `,` según convención)
# 3. Convertir con `pd.to_numeric(..., errors="coerce")`
#
# **Rol:** llevar datos a tipo numérico para poder calcular.

# %%
# Limpieza de precio_unitario a numérico (COP)
precio_txt = df["precio_unitario"].astype("string").str.strip()

# Quitar símbolos y espacios
precio_txt = (precio_txt
              .str.replace("$", "", regex=False)
              .str.replace(" ", "", regex=False)
             )

# Quitar separadores de miles tipo "." (ej: 120.000 -> 120000)
precio_txt = precio_txt.str.replace(".", "", regex=False)

df["precio_cop"] = pd.to_numeric(precio_txt, errors="coerce")

# Unidades a numérico (puede tener faltantes)
df["unidades"] = pd.to_numeric(df["unidades"], errors="coerce")

df[["precio_unitario", "precio_cop", "unidades"]]

# %% [markdown]
# ### 🧩 Tu turno (6–8 min)
#
# 1. Crea una columna `venta_cop = unidades * precio_cop`.
# 2. Identifica cuántos valores faltantes hay en `unidades`, `ciudad` y `fecha_dt`.
# 3. Rellena los faltantes de `unidades` con la mediana (solo en este dataset de ejemplo).
#
# > Pista: `df["unidades"].fillna(df["unidades"].median())`

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 4.4 Duplicados
#
# Funciones clave:
# - `df.duplicated()`: marca duplicados
# - `df.drop_duplicates()`: elimina duplicados
#
# **Rol:** evitar doble conteo (ventas repetidas, registros replicados).

# %%
# ¿Cuántas filas duplicadas hay?
df.duplicated().sum()

# %%
df = df.drop_duplicates()
df.shape

# %% [markdown]
# ## 4.5 Tratamiento de faltantes (missing data)
#
# Patrones comunes:
#
# - `.isna()` / `.sum()`: diagnosticar
# - `.dropna(subset=[...])`: eliminar filas si son inservibles
# - `.fillna(valor)` o `.fillna(mediana/ moda)`: imputación simple
#
# **Rol:** preparar dataset para análisis/modelado.

# %%
df.isna().sum()

# %% [markdown]
# # 5. Análisis con pandas: `groupby`, `agg` y `pivot_table`
#
# Una vez limpio el dataset, podemos responder preguntas como:
#
# - ¿Cuánto vendimos por ciudad?
# - ¿Qué canal vende más?
# - ¿Cuál es el ticket promedio por canal?
#
# Funciones clave:
# - `groupby(...).agg(...)`
# - `value_counts()`
# - `pivot_table(...)`
# - `sort_values(...)`

# %%
# Asegurar venta_cop (si aún no existe)
if "venta_cop" not in df.columns:
    df["venta_cop"] = df["unidades"] * df["precio_cop"]

resumen_ciudad = (df
                  .groupby("ciudad", dropna=False)
                  .agg(ventas=("venta_cop", "sum"),
                       unidades=("unidades", "sum"),
                       n_registros=("id_venta", "count"))
                  .sort_values("ventas", ascending=False)
                 )

resumen_ciudad

# %% [markdown]
# ### 🧩 Tu turno (8–10 min)
#
# 1. Calcula ventas totales por `canal`.
# 2. Calcula la **venta promedio** por canal (promedio de `venta_cop`).
# 3. Ordena de mayor a menor por ventas.
#
# > Pista: `groupby("canal").agg(...)`

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 5.1 `pivot_table` para resúmenes tipo “tabla dinámica”
#
# `pivot_table` es útil cuando quieres cruzar dos dimensiones, por ejemplo:
#
# - filas = ciudad
# - columnas = canal
# - valores = ventas (suma)

# %%
tabla = pd.pivot_table(
    df,
    index="ciudad",
    columns="canal",
    values="venta_cop",
    aggfunc="sum",
    fill_value=0
)

tabla

# %% [markdown]
# ### 🧩 Tu turno (6–8 min)
#
# 1. Crea una `pivot_table` con filas = `producto`, columnas = `canal`, valores = `venta_cop` (suma).
# 2. Agrega una columna `total` a la tabla con el total por fila.
# 3. Identifica el producto con mayor total.

# %%
# Escribe tu solución aquí

# %% [markdown]
# # 6. Transformación: variables nuevas y segmentación
#
# Ejemplos típicos en ciencia de datos:
#
# - Variables derivadas (`venta_cop`, `mes`, `día_semana`)
# - Segmentación por cuantiles (RFM, niveles de gasto) con `qcut`
# - Binning por rangos con `cut`

# %%
# Variables derivadas de fecha
df["mes"] = df["fecha_dt"].dt.to_period("M").astype("string")
df["dia_semana"] = df["fecha_dt"].dt.day_name()

# Segmentación simple por cuantiles del valor de venta (bajo/medio/alto)
df["segmento_venta"] = pd.qcut(df["venta_cop"], q=3, labels=["bajo", "medio", "alto"])

df[["fecha_dt", "mes", "dia_semana", "venta_cop", "segmento_venta"]].head(10)

# %% [markdown]
# ### 🧩 Tu turno (6–8 min)
#
# 1. Crea una columna `es_online` que valga 1 si `canal == "online"` y 0 en caso contrario.
# 2. Crea una columna `precio_categoria` usando `pd.cut`:
#    - barato: precio_cop < 60000
#    - medio: 60000 a 200000
#    - premium: > 200000
# 3. Haz un `groupby` por `precio_categoria` y calcula ventas totales.

# %%
# Escribe tu solución aquí

# %% [markdown]
# # 7. Integración de datos: `merge` y `concat`
#
# En proyectos reales, casi nunca tienes “una sola tabla”.
#
# - `merge`: unir tablas por claves (similar a JOIN en SQL).
# - `concat`: apilar (vertical u horizontal) varias tablas.
#
# **Rol:** construir un dataset maestro combinando fuentes.

# %%
# Tabla de referencia: categoría por producto
ref_producto = pd.DataFrame({
    "producto": ["mouse", "teclado", "monitor", "headset"],
    "categoria": ["accesorios", "accesorios", "pantallas", "audio"]
})
ref_producto

# %%
# Nota: aseguramos que producto esté limpio y en minúscula
df["producto"] = df["producto"].astype("string").str.strip().str.lower()

df_merged = df.merge(ref_producto, on="producto", how="left")
df_merged[["producto", "categoria"]]

# %% [markdown]
# ### 🧩 Tu turno (5–7 min)
#
# 1. Después del `merge`, calcula ventas totales por `categoria`.
# 2. Identifica si hay productos sin categoría (valores `NaN` en `categoria`) y lista cuáles son.

# %%
# Escribe tu solución aquí
